# %%
import meshflow

# %%
exp = meshflow.MESHWorkflow.from_json_file("mesh.json")

# %%
exp.outlet_value = 0

# %%
exp.run()
# Out:
# /home/kasra.keshavarz1/virtual-envs/maf-paper/lib/python3.11/site-packages/meshflow/utility/forcing_prep.py:128: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   var = [i for i in ds.dims.keys() if i != 'time']
# /home/kasra.keshavarz1/virtual-envs/maf-paper/lib/python3.11/site-packages/meshflow/core.py:909: UserWarning: GRU 1 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# /home/kasra.keshavarz1/virtual-envs/maf-paper/lib/python3.11/site-packages/meshflow/core.py:909: UserWarning: GRU 2 not found in landcover classes. Skipping...
#   warnings.warn(f"GRU {gru} not found in landcover classes. Skipping...")
# ...

# %%
exp.forcing
# Out:
# <xarray.Dataset> Size: 968B
# Dimensions:                (subbasin: 0, time: 120)
# Coordinates:
#   * time                   (time) datetime64[ns] 960B 1980-01-01 ... 1980-01-...
#   * subbasin               (subbasin) int32 0B
# Data variables:
#     CaSR_v3.1_P_P0_SFC     (subbasin, time) float64 0B
#     CaSR_v3.1_P_HU_09975   (subbasin, time) float64 0B
#     CaSR_v3.1_P_TT_09975   (subbasin, time) float64 0B
#     CaSR_v3.1_P_UVC_09975  (subbasin, time) float64 0B
#     CaSR_v3.1_A_PR0_SFC    (subbasin, time) float64 0B
#     CaSR_v3.1_P_FB_SFC     (subbasin, time) float64 0B
#     CaSR_v3.1_P_FI_SFC     (subbasin, time) float64 0B
#     lat                    (subbasin) float64 0B
#     lon                    (subbasin) float64 0B
#     crs                    int64 8B 1
# Attributes:
#     author:       University of Calgary
#     license:      GNU General Public License v3 (or any later version)
#     purpose:      Create forcing .nc file for MESH
#     Conventions:  CF-1.6
# ...
